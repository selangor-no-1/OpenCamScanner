# %%
from backend.api.cv import scan, load_and_compress
import matplotlib.pyplot as plt
import os

# %%
paths = [os.path.join("backend/experiments/images", img) for img in os.listdir("backend/experiments/images")]

# %%
imgs = load_and_compress(paths)

# %%
res = scan(imgs[0])

# %%
plt.subplot(1,2,1)
plt.title("Original")
plt.imshow(imgs[0])
plt.subplot(1,2,2)
plt.title("Processed")
plt.imshow(res, cmap="gray")
